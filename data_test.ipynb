# %%
import random

data = {
    "review_id": list(range(1, 95)),  # Review IDs from 1 to 100
    "review_text": [
    "Amazing product! Works perfectly.",
    "Very disappointed. It broke after a week.",
    "Okay item, does the job.",
    "Excellent quality, highly recommend!",
    "Not what I expected. Could be better.",
    "This product is just what I needed, very happy with it!",
    "Terrible experience, would not buy again.",
    "It’s fine, but not great. Just average.",
    "Fantastic! Surpassed my expectations.",
    "It’s decent, but could use some improvements.",
    "Best purchase I’ve made this year!",
    "Absolute waste of money.",
    "Meh. It works, but I’m not thrilled.",
    "Totally worth it! High quality.",
    "This is the second one I’ve bought. Love it!",
    "I wanted something better for the price.",
    "So-so. It’s functional but lacks durability.",
    "Perfect for my needs. Couldn’t be happier.",
    "Complete disaster. I’m returning it.",
    "Good quality overall, though not outstanding.",
    "Superb performance and very reliable.",
    "Not worth the hype. Disappointing.",
    "Great value for money! I’m impressed.",
    "I regret buying this. Low quality.",
    "Average experience. Not bad, not great.",
    "Highly recommend this to everyone.",
    "The product feels cheap and poorly made.",
    "Fantastic! It’s a game changer.",
    "Wouldn’t recommend. It’s just not good.",
    "It does what it says. Satisfied.",
    "Phenomenal quality, well worth the price.",
    "Awful experience. Customer support didn’t help.",
    "This exceeded my expectations. Love it!",
    "Mediocre at best. Needs improvement.",
    "Thrilled with this purchase. Amazing product!",
    "I’m underwhelmed. Expected more.",
    "Great features and easy to use.",
    "It’s functional, but I wouldn’t buy again.",
    "Very pleased! I’ll buy another one.",
    "Big disappointment. Don’t waste your money.",
    "Sturdy and reliable. Great product!",
    "Horrible quality. Falling apart after a month.",
    "Decent value. Meets my needs.",
    "Top-notch product! Highly recommend.",
    "Could be better. It’s just okay.",
    "Excellent build quality. Worth every penny.",
    "So bad I returned it the next day.",
    "Does the job, but nothing special.",
    "Perfect for the price. Really happy.",
    "Terrible purchase. Wouldn’t recommend.",
    "Exceeded my expectations. Fantastic buy!",
    "Very poor performance. Avoid this product.",
    "Great performance and reliable.",
    "Not great, not terrible. It’s fine.",
    "Absolutely love it! Will buy more.",
    "Not as advertised. A huge letdown.",
    "Great product. Very satisfied.",
    "Waste of money. Do not buy.",
    "Just okay. It works, but I’m not impressed.",
    "Amazing performance. Highly recommend.",
    "Couldn’t be happier! Fantastic product.",
    "Rubbish. Completely useless.",
    "Good for the price, but not the best.",
    "Best product I’ve ever purchased!",
    "Broken on arrival. Terrible experience.",
    "Works well. I’d buy it again.",
    "Disappointing quality for the cost.",
    "Does what it’s supposed to. Satisfied.",
    "High quality, well designed. Love it.",
    "Below average. Expected more.",
    "Fantastic features and performance!",
    "Horrible. I regret this purchase.",
    "Overall, very pleased with it.",
    "Falls short of expectations.",
    "Reliable and works perfectly.",
    "Wouldn’t recommend. Too many issues.",
    "It’s great! I’ll recommend it to others.",
    "Came broken. A total disaster.",
    "Highly recommended! Outstanding quality.",
    "Not what I hoped for. Needs improvement.",
    "I’m very impressed. Great quality.",
    "Disappointed. Not worth the money.",
    "Super easy to set up and use.",
    "Terrible experience. I want a refund.",
    "It’s fine, but I wouldn’t buy it again.",
    "Works as described. No complaints.",
    "Low quality. Definitely not buying again.",
    "Superb! Can’t live without it now.",
    "Terrible build quality. Stay away.",
    "Perfect for my needs. Really happy with it.",
    "Not great. Better options out there.",
    "Would buy again. Highly satisfied.",
    "Total waste of money. Don’t bother.",
    "Great purchase. Couldn’t be more satisfied."
],
    "rating": [random.randint(1, 5) for _ in range(94)]  # Random ratings between 1 and 5
}

# %%
# Check lengths
len_review_id = len(data["review_id"])
len_review_text = len(data["review_text"])
len_rating = len(data["rating"])

print(f"Length of review_id: {len_review_id}")
print(f"Length of review_text: {len_review_text}")
print(f"Length of rating: {len_rating}")
# Out:
# Length of review_id: 94
# Length of review_text: 94
# Length of rating: 94

# %%
import pandas as pd
data_df = pd.DataFrame(data)
data_df.head()
# Out:
#    review_id                                review_text  rating
# 0          1          Amazing product! Works perfectly.       4
# 1          2  Very disappointed. It broke after a week.       2
# 2          3                   Okay item, does the job.       4
# 3          4       Excellent quality, highly recommend!       2
# 4          5      Not what I expected. Could be better.       4

# %%
data_df.to_csv("../Sentiment Analysis/Data/data.csv")

# %%
test_text = ["This is the best product I’ve ever used."]
test_vector = vectorizer.transform(test_text)
predicted_label = model.predict(test_vector)
print("Prediction:", "Positive" if predicted_label[0] == 1 else "Negative")
